# %% [markdown]
# <img src="1.png">

# %% [markdown]
# <center><h1>Solutions</h1></center>

# %% [markdown]
# ### Task 1

# %%
for i in range(1500,2701):
    if i%7==0:
        print("%d is divisible by 7" % (i))
    if i%5==0:
        print("%d is multiple of 5" % (i))
# Out:
# 1500 is multiple of 5
# 1505 is divisible by 7
# 1505 is multiple of 5
# 1510 is multiple of 5
# 1512 is divisible by 7
# 1515 is multiple of 5
# 1519 is divisible by 7
# 1520 is multiple of 5
# 1525 is multiple of 5
# 1526 is divisible by 7
# 1530 is multiple of 5
# 1533 is divisible by 7
# 1535 is multiple of 5
# 1540 is divisible by 7
# 1540 is multiple of 5
# 1545 is multiple of 5
# 1547 is divisible by 7
# 1550 is multiple of 5
# 1554 is divisible by 7
# 1555 is multiple of 5
# 1560 is multiple of 5
# 1561 is divisible by 7
# 1565 is multiple of 5
# 1568 is divisible by 7
# 1570 is multiple of 5
# 1575 is divisible by 7
# 1575 is multiple of 5
# 1580 is multiple of 5
# 1582 is divisible by 7
# 1585 is multiple of 5
# 1589 is divisible by 7
# 1590 is multiple of 5
# 1595 is multiple of 5
# 1596 is divisible by 7
# 1600 is multiple of 5
# 1603 is divisible by 7
# 1605 is multiple of 5
# 1610 is divisible by 7
# 1610 is multiple of 5
# 1615 is multiple of 5
# ...

# %% [markdown]
# ### Task 2

# %%
# cel/5 = far - (32/9)
# far = cel/5+(32/9)
cel = float(input("Enter Censious temperature"))
far = float(cel*9/5+32)
print("Fahrenheit Temperature is %f " % (far))
# Out:
# Enter Censious temperature34
# Fahrenheit Temperature is 93.200000

# %% [markdown]
# ### Task 3

# %%
n = int(input("Enter a number"))
if n%2==1:
    print("Ok")
else:
    if n>=2 and n<=5:
        print("Not Ok")
    elif n>=6 and n<=20:
        print("Ok")
    elif n>20:
        print("OK")
# Out:
# Enter a number5
# Ok
